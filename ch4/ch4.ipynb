# %%
import pandas as pd
df = pd.read_csv("tips.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df["tip_percentage"] = 100 * df["tip"] /df["total_bill"]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
df["price_per_person"] = df["total_bill"]/df["size"]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2          8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3          3.446667
# 2       21.01  3.50    Male     No  Sun  Dinner     3          7.003333
# 3       23.68  3.31    Male     No  Sun  Dinner     2         11.840000
# 4       24.59  3.61  Female     No  Sun  Dinner     4          6.147500
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
import numpy as np
df["price_per_person"] = np.round(df["price_per_person"],2)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
df.drop("tip_percentage",axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.set_index("Payment ID",inplace=True)

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df.iloc[0]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.loc["Sun4608"]
# Out:
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                3.45
# Payer Name            Douglas Tucker
# CC Number           4478071379779230
# Name: Sun4608, dtype: object

# %%
df.iloc[1:4]
# Out:
#             total_bill   tip   sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66  Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50  Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31  Male     No  Sun  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# Sun4458                 7.00    Travis Walters  6011812112971322
# Sun5260                11.84  Nathaniel Harris  4676137647685994

# %%
df.loc["Sun4608":"Sun5260"]
# Out:
#             total_bill   tip   sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66  Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50  Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31  Male     No  Sun  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# Sun4458                 7.00    Travis Walters  6011812112971322
# Sun5260                11.84  Nathaniel Harris  4676137647685994

# %%
df.loc[["Sun4458","Sun2959","Sun2251"]]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df.iloc[[0,2,3]]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
df.drop("Sun5260",axis=0).head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun2251                 6.15        Tonya Carter  4832732618637221
# Sun9679                 6.32          Erik Smith   213140353657882

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
one_row = df.iloc[0]
one_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
type(one_row)
# Out:
# pandas.core.series.Series

# %%
df.tail()
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person       Payer Name         CC Number
# Payment ID
# Sat2657                 9.68    Michael Avila  5296068606052842
# Sat1766                13.59   Monica Sanders  3506806155565404
# Sat3880                11.34       Keith Wong  6011891618747196
# Sat17                   8.91     Dennis Dixon     4375220550950
# Thur672                 9.39  Michelle Hardin  3511451626698139

# %%
one_row_df = one_row.to_frame().T
one_row_df
# Out:
#         total_bill   tip     sex smoker  day    time size price_per_person  \
# Sun2959      16.99  1.01  Female     No  Sun  Dinner    2             8.49
#
#                  Payer Name         CC Number
# Sun2959  Christy Cunningham  3560325168603410

# %%
pd.concat([df,one_row_df],ignore_index=True)
# Out:
#     total_bill   tip     sex smoker   day    time size price_per_person  \
# 0        16.99  1.01  Female     No   Sun  Dinner    2             8.49
# 1        10.34  1.66    Male     No   Sun  Dinner    3             3.45
# 2        21.01   3.5    Male     No   Sun  Dinner    3              7.0
# 3        23.68  3.31    Male     No   Sun  Dinner    2            11.84
# 4        24.59  3.61  Female     No   Sun  Dinner    4             6.15
# ..         ...   ...     ...    ...   ...     ...  ...              ...
# 240      27.18   2.0  Female    Yes   Sat  Dinner    2            13.59
# 241      22.67   2.0    Male    Yes   Sat  Dinner    2            11.34
# 242      17.82  1.75    Male     No   Sat  Dinner    2             8.91
# 243      18.78   3.0  Female     No  Thur  Dinner    2             9.39
# 244      16.99  1.01  Female     No   Sun  Dinner    2             8.49
#
#              Payer Name         CC Number
# 0    Christy Cunningham  3560325168603410
# ...

# %%
bool_series = df["total_bill"] > 30

# %%
df[bool_series].head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun6686          35.26  5.00  Female     No  Sun  Dinner     4
# Sat239           39.42  7.58    Male     No  Sat  Dinner     4
# Sat6373          31.27  5.00    Male     No  Sat  Dinner     3
# Sun2274          30.40  5.60    Male     No  Sun  Dinner     4
# Sun9677          32.40  6.00    Male     No  Sun  Dinner     4
#
#             price_per_person         Payer Name         CC Number
# Payment ID
# Sun6686                 8.82       Diane Macias  4577817359320969
# Sat239                  9.86     Lance Peterson  3542584061609808
# Sat6373                10.42  Mr. Brandon Berry  6011525851069856
# Sun2274                 7.60        Todd Cooper      503846761263
# Sun9677                 8.10       James Barnes  3552002592874186

# %%
df[df["total_bill"] > 30].head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun6686          35.26  5.00  Female     No  Sun  Dinner     4
# Sat239           39.42  7.58    Male     No  Sat  Dinner     4
# Sat6373          31.27  5.00    Male     No  Sat  Dinner     3
# Sun2274          30.40  5.60    Male     No  Sun  Dinner     4
# Sun9677          32.40  6.00    Male     No  Sun  Dinner     4
#
#             price_per_person         Payer Name         CC Number
# Payment ID
# Sun6686                 8.82       Diane Macias  4577817359320969
# Sat239                  9.86     Lance Peterson  3542584061609808
# Sat6373                10.42  Mr. Brandon Berry  6011525851069856
# Sun2274                 7.60        Todd Cooper      503846761263
# Sun9677                 8.10       James Barnes  3552002592874186

# %%
df[df["sex"] == "Male"].describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  157.000000  157.000000  157.000000        157.000000  1.570000e+02
# mean    20.744076    3.089618    2.630573          8.123057  2.626112e+15
# std      9.246469    1.489102    0.955997          3.119916  2.397656e+15
# min      7.250000    1.000000    1.000000          3.450000  6.040679e+10
# 25%     14.000000    2.000000    2.000000          5.860000  3.623118e+13
# 50%     18.350000    3.000000    2.000000          7.600000  3.527691e+15
# 75%     24.710000    3.760000    3.000000          9.680000  4.563054e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df[df["sex"] == "Female"].describe()
# Out:
#        total_bill        tip       size  price_per_person     CC Number
# count   87.000000  87.000000  87.000000         87.000000  8.700000e+01
# mean    18.056897   2.833448   2.459770          7.464368  2.450499e+15
# std      8.009209   1.159495   0.937644          2.461255  2.326826e+15
# min      3.070000   1.000000   1.000000          2.880000  6.046330e+10
# 25%     12.750000   2.000000   2.000000          5.685000  4.859865e+12
# 50%     16.400000   2.750000   2.000000          6.710000  3.508912e+15
# 75%     21.520000   3.500000   3.000000          8.725000  4.447818e+15
# max     44.300000   6.500000   6.000000         14.770000  6.542729e+15

# %%
df[(df["total_bill"] > 30) & (df["sex"] == "Male")]
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26  5.00  Female     No   Sun  Dinner     4
# Sun6165          34.81  5.20  Female     No   Sun  Dinner     4
# Thur7972         34.83  5.17  Female     No  Thur   Lunch     4
# Sat6240          44.30  2.50  Female    Yes   Sat  Dinner     3
# Thur9313         43.11  5.00  Female    Yes  Thur   Lunch     4
# Sat8863          30.14  3.09  Female    Yes   Sat  Dinner     4
# Sat9777          35.83  4.67  Female     No   Sat  Dinner     3
#
#             price_per_person      Payer Name         CC Number
# Payment ID
# Sun6686                 8.82    Diane Macias  4577817359320969
# Sun6165                 8.70    Emily Daniel  4291280793094374
# Thur7972                8.71     Shawna Cook  6011787464177340
# Sat6240                14.77   Heather Cohen   379771118886604
# Thur9313               10.78     Brooke Soto  5544902205760175
# ...

# %%
df[(df["total_bill"] > 30) & ~(df["sex"] == "Male")]#~不是
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26  5.00  Female     No   Sun  Dinner     4
# Sun6165          34.81  5.20  Female     No   Sun  Dinner     4
# Thur7972         34.83  5.17  Female     No  Thur   Lunch     4
# Sat6240          44.30  2.50  Female    Yes   Sat  Dinner     3
# Thur9313         43.11  5.00  Female    Yes  Thur   Lunch     4
# Sat8863          30.14  3.09  Female    Yes   Sat  Dinner     4
# Sat9777          35.83  4.67  Female     No   Sat  Dinner     3
#
#             price_per_person      Payer Name         CC Number
# Payment ID
# Sun6686                 8.82    Diane Macias  4577817359320969
# Sun6165                 8.70    Emily Daniel  4291280793094374
# Thur7972                8.71     Shawna Cook  6011787464177340
# Sat6240                14.77   Heather Cohen   379771118886604
# Thur9313               10.78     Brooke Soto  5544902205760175
# ...

# %%
df[(df["day"] == "Sun") | (df["day"] == "Sat") ]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat9777          35.83  4.67  Female     No  Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75    Male     No  Sat  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
options = ["Sat","Sun"]
df["day"].isin(options)
# Out:
# Payment ID
# Sun2959     True
# Sun4608     True
# Sun4458     True
# Sun5260     True
# Sun2251     True
#            ...
# Sat2657     True
# Sat1766     True
# Sat3880     True
# Sat17       True
# Thur672    False
# Name: day, Length: 244, dtype: bool

# %%
df[df["day"].isin(options)]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat9777          35.83  4.67  Female     No  Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75    Male     No  Sat  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
import pandas as pd
df = pd.read_csv("starbucks.csv",index_col="Date",parse_dates=True)
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df["Close"].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
newDf = df.rolling(window=5).mean()

# %%
newDf
# Out:
#                Close      Volume
# Date
# 2015-01-02       NaN         NaN
# 2015-01-05       NaN         NaN
# 2015-01-06       NaN         NaN
# 2015-01-07       NaN         NaN
# 2015-01-08  37.72798   9819467.2
# ...              ...         ...
# 2018-12-24  62.61600  15005336.0
# 2018-12-26  62.24800  16229888.4
# 2018-12-27  62.07600  15613475.4
# 2018-12-28  62.32400  13102917.2
# 2018-12-31  62.92600   9935976.2
#
# [1006 rows x 2 columns]

# %%
df["Close"].plot(figsize=(12,5))
df.rolling(window=5).mean()["Close"].plot(figsize=(12,5))
df.rolling(window=10).mean()["Close"].plot(figsize=(12,5))
df.rolling(window=60).mean()["Close"].plot(figsize=(12,5))
df.rolling(window=120).mean()["Close"].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
## 作業
def last_four(num):
    pass
#希望傳入一個字串可幫我取得後四碼
#"3560325168603410"
